# %%
import ultralytics
from ultralytics import YOLO

model = YOLO("best.pt")

# %%
results = model.predict(source="7056755-uhd_2160_3744_30fps.mp4", save=True, show=False)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1481) d:\Mycode\try\yolov8-live\7056755-uhd_2160_3744_30fps.mp4: 640x384 66 BIODEGRADABLEs, 337.4ms
# video 1/1 (frame 2/1481) d:\Mycode\try\yolov8-live\7056755-uhd_2160_3744_30fps.mp4: 640x384 60 BIODEGRADABLEs, 361.1ms
# video 1/1 (frame 3/1481) d:\Mycode\try\yolov8-live\7056755-uhd_2160_3744_30fps.mp4: 640x384 60 BIODEGRADABLEs, 317.5ms
# ...
